# %% [markdown]
# # Nanobody feature extractor

# %% [markdown]
# ## 1. Secondary structure elements

# %%
from Bio.PDB import PDBParser, DSSP
from nanobody_feature_extractor import NanobodyFeatureExtractor

# %%
extractor=NanobodyFeatureExtractor(use_pymol=True)
features_df=extractor.process_directory(r"\\wsl.localhost\Debian\home\lara\data_project")
extractor.save_results("nanobody_features.json")

print(features_df.head())
# Out:
# WSL scripts set up at: /tmp/tmp.1SMQGG1jNV
# Processing 3035 PDB files...
#   0%|          | 0/3035 [00:00<?, ?it/s]
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# ...
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# PyMOL error:   File "/tmp/tmp.1SMQGG1jNV/extract_ss.py", line 2
#     import pymol
# IndentationError: unexpected indent
#
# Results saved to nanobody_features.json
# Results also saved to nanobody_features.csv
#                  helix_percent  sheet_percent  coil_percent  total_residues  \
# 7RTH_nanobody_e              0              0             0               0
# 8HSC_nanobody_F              0              0             0               0
# 8Q7O_nanobody_A              0              0             0               0
# 7N0I_nanobody_D              0              0             0               0
# 6Z6V_nanobody_G              0              0             0               0
#
#                  atom_count  residue_count  atoms_per_residue
# 7RTH_nanobody_e         978            131           7.465649
# 8HSC_nanobody_F         925            122           7.581967
# 8Q7O_nanobody_A         931            144           6.465278
# 7N0I_nanobody_D         850            178           4.775281
# 6Z6V_nanobody_G         969            160           6.056250

# %%
features_df
# Out:
#                  helix_percent  sheet_percent  coil_percent  total_residues  \
# 7RTH_nanobody_e              0              0             0               0
# 8HSC_nanobody_F              0              0             0               0
# 8Q7O_nanobody_A              0              0             0               0
# 7N0I_nanobody_D              0              0             0               0
# 6Z6V_nanobody_G              0              0             0               0
# ...                        ...            ...           ...             ...
# 7Y0N_nanobody_I              0              0             0               0
# 7ZQT_nanobody_B              0              0             0               0
# 8AHL_nanobody_E              0              0             0               0
# 7KKL_nanobody_E              0              0             0               0
# 8YAT_nanobody_N              0              0             0               0
#
#                  atom_count  residue_count  atoms_per_residue
# 7RTH_nanobody_e         978            131           7.465649
# 8HSC_nanobody_F         925            122           7.581967
# 8Q7O_nanobody_A         931            144           6.465278
# 7N0I_nanobody_D         850            178           4.775281
# 6Z6V_nanobody_G         969            160           6.056250
# ...                     ...            ...                ...
# 7Y0N_nanobody_I         947            123           7.699187
# 7ZQT_nanobody_B         844            110           7.672727
# 8AHL_nanobody_E         869            112           7.758929
# 7KKL_nanobody_E        1752            118          14.847458
# 8YAT_nanobody_N         865            115           7.521739
#
# [3035 rows x 7 columns]
