# %%
import  as structured
print(dir(structured))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import proteinAnalysis as structured
#       2 print(dir(structured))
#
# ModuleNotFoundError: No module named 'proteinAnalysis'
