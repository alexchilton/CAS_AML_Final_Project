# %%
import importlib
import sys
import os

# Add the parent directory to the Python path
module_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Import the preprocessing package
import preprocessing

# Get the classes - they're accessible directly from the package
ProteinPreprocessor = preprocessing.ProteinPreprocessor
ProteinVisualizer = preprocessing.ProteinVisualizer
GraphBuilder = preprocessing.GraphBuilder
FeatureExtractor = preprocessing.FeatureExtractor

# Function to reload the package and get updated classes
def reload_modules():
    importlib.reload(preprocessing)
    print("Modules reloaded successfully!")
    return preprocessing.ProteinPreprocessor, preprocessing.ProteinVisualizer

# Create instances
preprocessor = ProteinPreprocessor()
visualizer = ProteinVisualizer()
