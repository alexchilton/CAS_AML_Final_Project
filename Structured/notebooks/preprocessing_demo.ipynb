# %%
import importlib
import sys
import os

import protein_preprocessor
import protein_visualizer
from protein_preprocessor import ProteinPreprocessor
from protein_visualizer import ProteinVisualizer

# %%
def reload_modules():
    # Reload the modules
    importlib.reload(protein_preprocessor)
    importlib.reload(protein_visualizer)

    # Re-import the classes
    from protein_preprocessor import ProteinPreprocessor
    from protein_visualizer import ProteinVisualizer

    print("Modules reloaded successfully!")

    # Return the classes for convenience
    return ProteinPreprocessor, ProteinVisualizer

# %%
ProteinPreprocessor, ProteinVisualizer = reload_modules()
