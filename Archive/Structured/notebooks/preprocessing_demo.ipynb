# %%
import importlib
import sys
import os

from Structured import *


# Get the classes - they're accessible directly from the package
ProteinPreprocessor = ProteinPreprocessor
ProteinVisualizer = ProteinVisualizer
#GraphBuilder = GraphBuilder
FeatureExtractor = FeatureExtractor

# Function to reload the package and get updated classes
def reload_modules():
    import Structured

    importlib.reload(Structured)
    print("Modules reloaded successfully!")
    return Structured.ProteinPreprocessor, Structured.ProteinVisualizer

# Create instances
preprocessor = ProteinPreprocessor()
visualizer = ProteinVisualizer()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       2 import sys
#       3 import os
# ----> 5 from Structured import *
#       8 # Get the classes - they're accessible directly from the package
#       9 ProteinPreprocessor = ProteinPreprocessor
#
# File ~/DataspellProjects/CAS_AML_Final_Project/Structured/__init__.py:14
#      12 from .preprocessing.FeatureExtractor import FeatureExtractor
#      13 from .preprocessing.ProteinFeatureProcessor import ProteinFeatureProcessor
# ---> 14 from .preprocessing.ProteinGraphDataset import ProteinGraphDataset
#      16 from .model.Decoder import Decoder
#      17 from .model.Encoder import Encoder
#
# File ~/DataspellProjects/CAS_AML_Final_Project/Structured/preprocessing/__init__.py:7
#       5 from .FeatureExtractor import FeatureExtractor
#       6 from .ProteinFeatureProcessor import ProteinFeatureProcessor
# ...

# %%
preprocessor, visualizer = reload_modules()
# Out:
# Modules reloaded successfully!
